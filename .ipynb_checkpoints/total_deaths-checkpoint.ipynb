# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('total_deaths.csv')

# %%
df.head()
# Out:
#    Year  Population  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  Week 7  \
# 0  2020    67886011   12254   14058   12990   11856   11612   10986   10944
# 1  2019    66797000   10955   12609   11860   11740   11297   11660   11824
# 2  2018    66436000   12723   15050   14256   13935   13285   12495   12246
# 3  2017    66040200   11991   13715   13610   12877   12485   12269   11644
# 4  2016    65648000   13045   11501   11473   11317   11052   11170   10590
#
#    Week 8  ...  Week 44  Week 45  Week 46  Week 47  Week 48  Week 49  Week 50  \
# 0   10841  ...    10887    11812    12254    12535    12456    12303    12292
# 1   11295  ...    10164    10697    10650    10882    10958    10816    11188
# 2   12142  ...     9529    10151    10193     9957    10033    10287    10550
# 3   11794  ...     9984    10346    10275    10621    10538    10781    11217
# 4   11056  ...    10152    10470    10694    10603    10439    11223    10533
#
#    Week 51  Week 52  Week 53
# 0        0        0        0
# 1    11926     7533        0
# 2    11116     7131        0
# 3    12517     8487        0
# 4    11493     8003        0
#
# [5 rows x 55 columns]

# %%
min_week = 1
max_week = 50
population_correction = df['Population'] / df['Population'][0]
vals = np.array([df['Week %s' % s].values / population_correction for s in range(min_week, max_week + 1)]) 
mean_deaths = np.mean(vals[:,1:], axis=1)
std_deaths = np.std(vals[:,1:,], axis=1)
plt.figure(figsize=(12,8))
plt.fill_between(range(min_week, max_week + 1), mean_deaths - 2*std_deaths, mean_deaths + 2*std_deaths, color='#8CD3F5', label='2010-2019')
plt.fill_between(range(min_week, max_week + 1), mean_deaths - std_deaths, mean_deaths + std_deaths, color='#006FED', label='2010-2019')
plt.plot(range(min_week, max_week + 1), vals[:,0], color='red', linewidth=2, label='2020')
plt.xlabel('Week')
plt.ylabel('Deaths')
plt.axvline(12, linestyle=':')
plt.text(12.5, 18000, '1st Lockdown', rotation=90)
plt.axvline(44, linestyle=':')
plt.text(44.5, 18000, '2nd Lockdown', rotation=90)
plt.legend()
plt.title('Population adjusted UK weekly deaths')
plt.show()

# %%
def get_total_deaths(min_week, max_week):
    population_correction = df['Population'] / df['Population'][0]
    vals = np.array([df['Week %s' % s].values / population_correction for s in range(min_week, max_week + 1)]) 
    deaths = vals.sum(axis=0)
    mean_deaths = np.mean(deaths[1:])
    std_deaths = np.std(deaths[1:])
    return mean_deaths, std_deaths, deaths[0], deaths[0] - mean_deaths, (deaths[0] - mean_deaths) / std_deaths

# %%
get_total_deaths(10,25)
# Out:
# (164096.19620474376,
#  5122.554576895245,
#  220270.0,
#  56173.803795256244,
#  10.965974681582194)

# %%
get_total_deaths(26,40)
# Out:
# (139970.37387385135,
#  1839.6759583768571,
#  137121.0,
#  -2849.3738738513493,
#  -1.5488455240592192)

# %%
get_total_deaths(40,50)
# Out:
# (113376.77315210679,
#  2633.225383887367,
#  125711.0,
#  12334.22684789321,
#  4.6840756295932735)
