# %%
"""
Author: Adam Moss
Data from https://www.ons.gov.uk/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/weeklyprovisionalfiguresondeathsregisteredinenglandandwales
"""
# Out:
# '\nAuthor: Adam Moss\nData from https://www.ons.gov.uk/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/weeklyprovisionalfiguresondeathsregisteredinenglandandwales\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('all_cause_mortality/all_cause_mortality.csv')
df['population_correction'] = df['Population'][0] / df['Population']

# %%
df.head()
# Out:
#    Year  Population     1      2      3      4      5      6      7      8   \
# 0  2020    68065223  12254  14058  12990  11856  11612  10986  10944  10841
# 1  2019    67530172  10955  12609  11860  11740  11297  11660  11824  11295
# 2  2018    67141684  12723  15050  14256  13935  13285  12495  12246  12142
# 3  2017    66727461  11991  13715  13610  12877  12485  12269  11644  11794
# 4  2016    66297944  13045  11501  11473  11317  11052  11170  10590  11056
#
#    ...    45     46     47     48     49     50     51    52   53   \
# 0  ...  11812  12254  12535  12456  12303  12292  13011     0    0
# 1  ...  10697  10650  10882  10958  10816  11188  11926  7533    0
# 2  ...  10151  10193   9957  10033  10287  10550  11116  7131    0
# 3  ...  10346  10275  10621  10538  10781  11217  12517  8487    0
# 4  ...  10470  10694  10603  10439  11223  10533  11493  8003    0
#
#    population_correction
# 0               1.000000
# 1               1.007923
# 2               1.013755
# 3               1.020048
# 4               1.026657
#
# [5 rows x 56 columns]

# %%
min_week = 1
max_week = 50
vals = np.array([df['%s '% s].values * df['population_correction'] for s in range(min_week, max_week + 1)]) 
mean_deaths = np.mean(vals[:,1:], axis=1)
std_deaths = np.std(vals[:,1:,], axis=1)
plt.figure(figsize=(12,8))
plt.fill_between(range(min_week, max_week + 1), mean_deaths - 2*std_deaths, mean_deaths + 2*std_deaths, color='#8CD3F5', label='2010-2019')
plt.fill_between(range(min_week, max_week + 1), mean_deaths - std_deaths, mean_deaths + std_deaths, color='#006FED', label='2010-2019')
plt.plot(range(min_week, max_week + 1), vals[:,0], color='red', linewidth=2, label='2020')
plt.xlabel('Week')
plt.ylabel('Deaths')
plt.axvline(12, linestyle=':')
plt.text(12.5, 18000, '1st Lockdown', rotation=90)
plt.axvline(44, linestyle=':')
plt.text(44.5, 18000, '2nd Lockdown', rotation=90)
plt.legend()
plt.title('Population adjusted UK weekly deaths')
plt.savefig('plots/total_deaths.png')

# %%
def get_total_deaths(min_week, max_week):
    vals = np.array([df['%s ' % s].values * df['population_correction'] for s in range(min_week, max_week + 1)]) 
    deaths = vals.sum(axis=0)
    mean_deaths = np.mean(deaths[1:])
    std_deaths = np.std(deaths[1:])
    return mean_deaths, std_deaths, deaths[0], deaths[0] - mean_deaths, (deaths[0] - mean_deaths) / std_deaths

# %%
get_total_deaths(10,25)
# Out:
# (162648.98412539944,
#  5081.796429376477,
#  220270.0,
#  57621.01587460056,
#  11.33870997695012)

# %%
get_total_deaths(26,40)
# Out:
# (138737.15883148782,
#  1924.7112186933996,
#  137121.0,
#  -1616.1588314878172,
#  -0.8396889963497772)

# %%
get_total_deaths(40,50)
# Out:
# (112378.7318791077,
#  2694.7950560362547,
#  125711.0,
#  13332.268120892302,
#  4.947414494853124)
