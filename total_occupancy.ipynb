# %% [markdown]
# Author: Adam Moss
#
# Data from
#
# https://www.england.nhs.uk/statistics/statistical-work-areas/covid-19-hospital-activity/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import datetime

# %%
colors = ['#006FED', '#E03424', 'gray', '#009966', '#000866', '#336600', '#006633', 'm', 'r']

# %%
total_occupancy = pd.read_csv('covid_hospital_activity/total_beds.csv')
total_occupancy['Date'] = pd.to_datetime(total_occupancy['Date'])

# %%
total_occupancy
# Out:
#           Date  ENGLAND  East of England  London  Midlands  \
# 0   2020-08-01      879               85     126       216
# 1   2020-08-02      847               80     120       194
# 2   2020-08-03      842               73     122       206
# 3   2020-08-04      807               69     118       182
# 4   2020-08-05      805               70     111       181
# ..         ...      ...              ...     ...       ...
# 147 2020-12-26    18350             2269    4276      3233
# 148 2020-12-27    19277             2375    4591      3329
# 149 2020-12-28    20426             2524    4957      3515
# 150 2020-12-29    21787             2922    5371      3694
# 151 2020-12-30    22713             3111    5524      3876
#
#      North East and Yorkshire  North West  South East  South West
# 0                         117         191         123          21
# 1                         120         188         122          23
# ...

# %%
plt.figure(figsize=(18,10))
for i, region in enumerate(total_occupancy.columns.values[2:]):
    plt.plot(total_occupancy['Date'], total_occupancy[region], label=region, color=colors[i])
plt.title('COVID Total Bed Occupancy')
plt.legend()
plt.xlabel('Date')
ax = plt.gca()
ax.set_xlim([datetime.datetime(2020, 12, 1), datetime.datetime(2020, 12, 31)])
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d %b'))
plt.gcf().autofmt_xdate() # Rotation
plt.grid()
plt.savefig('plots/total_occupancy')
